# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ast


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
# https://www.geeksforgeeks.org/how-to-calculate-mean-absolute-error-in-python/#
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.feature_selection import f_regression


df = pd.read_csv(r"C:\Users\jjap2\Poleto SCE\Poleto-SCE\dond_game_data.csv")

# %%
# Excluding what might skew results
## probably should find a way to keep the current offer where the previous offer is not
df_c = df[(df["Postgame"] != 1) & (df["Offer"] != 0)]

# %%
df_c["Offer Percent of Average"].describe()
# Out:
# count    717.000000
# mean       0.548107
# std        0.284060
# min        0.000000
# 25%        0.318300
# 50%        0.534900
# 75%        0.776600
# max        1.400000
# Name: Offer Percent of Average, dtype: float64

# %%
sns.histplot(data=df_c['Offer Percent of Average'], kde=True)
# Out:
# <Axes: xlabel='Offer Percent of Average', ylabel='Count'>
